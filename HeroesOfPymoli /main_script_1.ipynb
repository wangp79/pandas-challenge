# %%
import pandas as pd

# File to Load (Remember to Change These)
file_to_load = "/Users/tony/Documents/GitHub/pandas-challenge/Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)

# %%
purchase_data_df = pd.DataFrame(purchase_data)

# %%
purchase_data_df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
total_players_sum = purchase_data_df['SN'].unique()
len(total_players_sum)
# Out:
# 576

# %%
unique_items_numbers = purchase_data_df['Item ID'].unique()
len(unique_items_numbers)
# Out:
# 179

# %%
purchase_data_df['Price'].mean()
# Out:
# 3.050987179487176

# %%
purchase_data_df['Purchase ID'].count()
# Out:
# 780

# %%
purchase_data_df['Price'].sum()
# Out:
# 2379.77

# %%
group_df = purchase_data_df.groupby(['Gender'])
group_df['SN'].describe()
# Out:
#                       count unique          top freq
# Gender
# Female                  113     81    Ialallo29    3
# Male                    652    484    Lisosia93    5
# Other / Non-Disclosed    15     11  Chanosian48    2

# %%
group_df.head()
# Out:
#      Purchase ID             SN  Age                 Gender  Item ID  \
# 0              0        Lisim78   20                   Male      108
# 1              1    Lisovynya38   40                   Male      143
# 2              2     Ithergue48   24                   Male       92
# 3              3  Chamassasya86   24                   Male      100
# 4              4      Iskosia90   23                   Male      131
# 9              9    Chanosian48   35  Other / Non-Disclosed      136
# 15            15      Lisassa64   21                 Female       98
# 18            18      Reunasu60   22                 Female       82
# 22            22   Siarithria38   38  Other / Non-Disclosed       24
# 38            38       Reulae52   10                 Female      116
# 41            41      Assosia88   20                 Female        7
# 55            55      Phaelap26   25                 Female       84
# 82            82     Haerithp41   16  Other / Non-Disclosed      160
# ...

# %%
group_df['Price'].sum()
# Out:
# Gender
# Female                    361.94
# Male                     1967.64
# Other / Non-Disclosed      50.19
# Name: Price, dtype: float64

# %%
group_df['Price'].mean()
# Out:
# Gender
# Female                   3.203009
# Male                     3.017853
# Other / Non-Disclosed    3.346000
# Name: Price, dtype: float64

# %%
group_df['Age'].max()
# Out:
# Gender
# Female                   40
# Male                     45
# Other / Non-Disclosed    38
# Name: Age, dtype: int64

# %%
group_df['Age'].min()
# Out:
# Gender
# Female                    7
# Male                      7
# Other / Non-Disclosed    15
# Name: Age, dtype: int64

# %%
bins = [0,9,14,19,24,29,34,39,40]
age_range = ['<10','10-14','15-19','20-24','25-29','30-34','35-39','40+']
purchase_data_df['age_ranges']= pd.cut(purchase_data_df['Age'],bins,labels = age_range, include_lowest=True)

# %%
purchase_data_df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price age_ranges
# 0  Extraction, Quickblade Of Trembling Hands   3.53      20-24
# 1                          Frenzied Scimitar   1.56        40+
# 2                               Final Critic   4.88      20-24
# 3                                Blindscythe   3.27      20-24
# 4                                       Fury   1.44      20-24

# %%
age_group = purchase_data_df.groupby(['age_ranges'])
age_group.head()
# Out:
#      Purchase ID             SN  Age                 Gender  Item ID  \
# 0              0        Lisim78   20                   Male      108
# 1              1    Lisovynya38   40                   Male      143
# 2              2     Ithergue48   24                   Male       92
# 3              3  Chamassasya86   24                   Male      100
# 4              4      Iskosia90   23                   Male      131
# 5              5        Yalae81   22                   Male       81
# 6              6      Itheria73   36                   Male      169
# 9              9    Chanosian48   35  Other / Non-Disclosed      136
# 14            14    Saesrideu94   35                   Male      165
# 19            19      Chamalo71   30                   Male       89
# 22            22   Siarithria38   38  Other / Non-Disclosed       24
# 23            23       Eyrian71   40                   Male      151
# 24            24        Siala43   30                   Male      132
# ...

# %%
age_sum = age_group['Price'].sum()
print(age_sum)
# Out:
# age_ranges
# <10        77.13
# 10-14      82.78
# 15-19     412.89
# 20-24    1114.06
# 25-29     293.00
# 30-34     214.00
# 35-39     147.67
# 40+        16.71
# Name: Price, dtype: float64

# %%
age_mean = age_group['Price'].mean()
print(age_mean)
# Out:
# age_ranges
# <10      3.353478
# 10-14    2.956429
# 15-19    3.035956
# 20-24    3.052219
# 25-29    2.900990
# 30-34    2.931507
# 35-39    3.601707
# 40+      2.785000
# Name: Price, dtype: float64

# %%
age_count = age_group['Purchase ID'].count()
print(age_count)
# Out:
# age_ranges
# <10       23
# 10-14     28
# 15-19    136
# 20-24    365
# 25-29    101
# 30-34     73
# 35-39     41
# 40+        6
# Name: Purchase ID, dtype: int64

# %%
age_demographics_table = {'Purchase Count':[age_count],'Average Purchase Price':[age_mean],'Total Purchase Value':[age_sum]}
age_table_df = pd.DataFrame(age_demographics_table)
age_table_df.head(10)
# Out:
#                                       Purchase Count  \
# 0  age_ranges
# <10       23
# 10-14     28
# 15-19    ...
#
#                               Average Purchase Price  \
# 0  age_ranges
# <10      3.353478
# 10-14    2.956429...
#
#                                 Total Purchase Value
# 0  age_ranges
# <10        77.13
# 10-14      82.78
# 1...

# %%
purchase_data_df['Item ID'].value_counts()
# Out:
# 92     13
# 178    12
# 108     9
# 82      9
# 145     9
#        ..
# 126     1
# 134     1
# 91      1
# 118     1
# 104     1
# Name: Item ID, Length: 179, dtype: int64

# %%
purchase_index = purchase_data_df.set_index(['Item ID'])
purchase_index.head()
# Out:
#          Purchase ID             SN  Age Gender  \
# Item ID
# 108                0        Lisim78   20   Male
# 143                1    Lisovynya38   40   Male
# 92                 2     Ithergue48   24   Male
# 100                3  Chamassasya86   24   Male
# 131                4      Iskosia90   23   Male
#
#                                          Item Name  Price age_ranges
# Item ID
# 108      Extraction, Quickblade Of Trembling Hands   3.53      20-24
# 143                              Frenzied Scimitar   1.56        40+
# 92                                    Final Critic   4.88      20-24
# 100                                    Blindscythe   3.27      20-24
# 131                                           Fury   1.44      20-24

# %%
popular_items= purchase_index.iloc[92,4]

# %%
print(popular_items)
# Out:
# Betrayal, Whisper of Grieving Widows
